# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._07_business_implication import BusinessRisk

except ImportError:
    print("Could not import module from `scripts/`.")

# %% [markdown]
# # **Complaint Business Implication Analysis**

# %%
# Define DataFrame path
processed_path = os.path.join(
    os.path.dirname(os.getcwd()), "data/processed/filtered_complaints.csv"
)
processed_dir = os.path.join(os.path.dirname(os.getcwd()), "data/processed")
plot_dir = os.path.join(os.path.dirname(os.getcwd()), "plots/05_business_implication")

# %%
# Initalise class and run pipeline
analysis = BusinessRisk(
    processed_path=processed_path, processed_dir=processed_dir, plot_dir=plot_dir
)
analysis.run_business_exposure_pipeline()
# Out:
# 🧪 Running Business Exposure Analysis Pipeline...
#
# 📥 DataFrame loaded from ..\data\processed\filtered_complaints.csv.
#
# 🔹 DataFrame columns:
#  ['Clean Narrative', 'Company', 'Company Public Response', 'Company Response To Consumer', 'Complaint Id', 'Complaint Length', 'Consumer Complaint Narrative', 'Consumer Consent Provided?', 'Consumer Disputed?', 'Date Received', 'Date Sent To Company', 'Issue', 'Product', 'State', 'Sub-Issue', 'Sub-Product', 'Submitted Via', 'Tags', 'Timely Response?', 'Zip Code']
#
# 🔹 Total number of issues: 456510
# Risk_Category
# Credit Reporting Errors     127813
# Billing Disputes            110067
# Investigation Failures       62871
# Access & Account Issues      49844
# Fraud & Unauthorized Use     45017
# Debt Collection Errors       23247
# Loan Servicing Problems      20637
# Customer Service Issues      17014
# Name: Issue, dtype: int64
# 💾 Plot saved to ..\plots\05_business_implication\Estimated Financial Exposure by Risk Category.png
# ...
