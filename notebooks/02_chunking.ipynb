# %% [markdown]
# # **Import Modules**

# %% [markdown]
# ## *python*

# %%
# Import python modules
import os
import sys

# %% [markdown]
# ## *custom*

# %%
# Import customised modules

# Define path
sys.path.append(os.path.abspath(os.path.join("..")))

# Import relevant modules
try:
    from scripts._02_chunking import Chunking

except ImportError:
    print("Could not import module from `scripts/`.")

# %% [markdown]
# # **Chunking**

# %%
# Define DataFrame path

df_path = os.path.join(
    os.path.dirname(os.getcwd()), "data/processed/filtered_complaints.csv"
)
plot_dir = os.path.join(os.path.dirname(os.getcwd()), "plots/02_chunking_embedding")
processed_dir = os.path.join(os.path.dirname(os.getcwd()), "data", "processed")

# %%
# Initalise class and run chunking and plotting

chunking = Chunking(df_path=df_path, plot_dir=plot_dir, processed_dir=processed_dir)
chunking.chunker()
# Out:
# 🧪 Running full Chunking pipeline...
#
# 📥 DataFrame loaded successfully from ..\data\processed\filtered_complaints.csv
#
# ✅ Sentence-aware chunking complete with max_words=100.
#
# Chunked DataFrame head:
#                                                Chunk  Chunk Length  \
# 0  a xxxx xxxx card was opened under my name by a...           487
# 1  i made the mistake of using my wellsfargo debi...           484
# 2  i went back into xxxx and they said they never...            67
# 3  i have a secured credit card with citibank whi...           438
# 4  they told me i have to wait for some form that...           361
#
#                                      Clean Narrative                Company  \
# 0  a xxxx xxxx card was opened under my name by a...         CITIBANK, N.A.
# 1  i made the mistake of using my wellsfargo debi...  WELLS FARGO & COMPANY
# 2  i made the mistake of using my wellsfargo debi...  WELLS FARGO & COMPANY
# ...
